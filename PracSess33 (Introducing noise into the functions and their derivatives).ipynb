# %%
# NUMERICAL DIFFERENTIATION WITH NOISE

# %% [markdown]
# f_epsilon,ω (x) = cos(x) + epsilon* sin(ωx) ;
# where 0 < epsilon<< 1 is a very small number, and ω is a large number. When epsilon is small, it is clear that f almost equal to f_epsilon,ω. To illustrate this point, we plot f_epsilon,ω (x) for epsilon = 0.01 and ω = 100,

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_grid = np.arange(0,2*np.pi,0.01)

omega = 100
epsilon_1 = 0.1
epsilon_2 = 0.01

# %%
def noise_fun(x_grid, epsilon, omega):
    y_noise = np.cos(x_grid) + epsilon*np.sin(omega*x_grid)
    
    return y_noise

# %%
y_noise_vec_1 = noise_fun(x_grid, epsilon_1, omega)
y_noise_vec_2 = noise_fun(x_grid, epsilon_2, omega)

# %%
plt.plot(x_grid, y, "b-", label = "Pure funcion")
plt.plot(x_grid, y_noise_vec_1, "r-", label = "Function with extra noise")

# %%
plt.plot(x_grid, y, "b-", label = "Pure funcion")
plt.plot(x_grid, y_noise_vec_2,  label = "Function with extra noise")

# %% [markdown]
# These are only the simple fucntions with noise, similarly we can introduce noise to the derivative functions and plot them.
